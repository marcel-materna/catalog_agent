# %%
import duckdb

# %%
# Verbindung zur bestehenden DuckDB-Datei herstellen
con = duckdb.connect(r"C:\Projekte\agent_duckdb\catalog_agent\data\metadata.duckdb")

# Tabellen anzeigen
print(con.execute("SHOW TABLES").fetchall())

# Daten aus einer Tabelle lesen
df = con.execute("SELECT * FROM energy_metadata").fetchdf()

# Optional: Ersten Datensatz anzeigen
display(df.head())

# Verbindung schließen
con.close()
# Out:
# [('energy_metadata',)]
#     dataset_id                     title  \
# 0  energy_0001         Ladedaten BW 2023
# 1  energy_0002   Verbrauchsdaten SN 2023
# 2  energy_0003   Speicherstatus NRW 2023
# 3  energy_0004         Ladedaten SH 2023
# 4  energy_0005  Verbrauchsdaten NRW 2022
#
#                                          description                publisher  \
# 0  Datensatz mit erzeugungsdaten aus BY für das J...             SolarFlow SE
# 1  Datensatz mit erzeugungsdaten aus SH für das J...       E-Mobility Connect
# 2  Datensatz mit speicherstatus aus HE für das Ja...       WattWise Analytics
# 3  Datensatz mit wetterdaten aus HE für das Jahr ...       E-Mobility Connect
# 4  Datensatz mit verbrauchsdaten aus SH für das J...  HydroEnergy Deutschland
#
#         source_system    data_category granularity geographical_scope  \
# 0       SmartMeterHub   Speicherstatus        1min                 BY
# 1       EdgeCollector  Erzeugungsdaten        1min                 BY
# 2       EdgeCollector        Ladedaten      hourly                NRW
# 3  EnergyDataPlatform   Speicherstatus       15min                 NI
# 4         IoT Gateway  Verbrauchsdaten       15min                NRW
#
#   temporal_coverage_start temporal_coverage_end   format  size_mb  \
# 0              2023-07-23            2024-01-30  Parquet   146.77
# 1              2023-10-10            2023-12-05  Parquet   186.54
# 2              2023-10-28            2024-07-07     JSON   125.07
# 3              2023-08-05            2024-02-14  Parquet   183.53
# 4              2022-11-21            2023-03-26      CSV    84.22
#
#   update_frequency      license          created_at       last_modified  \
# 0            daily  Proprietary 2022-06-22 17:15:51 2024-03-11 01:06:58
# 1          monthly  Proprietary 2023-05-25 21:36:43 2022-10-23 09:36:17
# 2           hourly  Proprietary 2022-03-29 23:48:11 2023-06-12 08:08:45
# 3           hourly    CC-BY-4.0 2022-06-25 09:32:38 2022-04-22 04:49:58
# 4          monthly       ODC-BY 2024-04-03 12:20:16 2023-09-27 13:52:57
#
#                      contact                            keywords  \
# 0   data-office@smartgrid.de                [solar, strom, netz]
# 1    data-office@wattwise.de         [verbrauch, wind, haushalt]
# 2  data-office@e-mobility.de  [wind, haushalt, zeitreihe, markt]
# 3    data-office@wattwise.de      [haushalt, netz, solar, markt]
# 4  data-office@e-mobility.de      [solar, verbrauch, wind, netz]
#
#    quality_score
# 0           0.66
# 1           0.99
# 2           0.66
# 3           0.98
# 4           0.79

# %%
df
# Out:
#      dataset_id                     title  \
# 0   energy_0001         Ladedaten BW 2023
# 1   energy_0002   Verbrauchsdaten SN 2023
# 2   energy_0003   Speicherstatus NRW 2023
# 3   energy_0004         Ladedaten SH 2023
# 4   energy_0005  Verbrauchsdaten NRW 2022
# ..          ...                       ...
# 95  energy_0096       Wetterdaten NI 2022
# 96  energy_0097          Netzlast BY 2023
# 97  energy_0098         Ladedaten BY 2023
# 98  energy_0099   Erzeugungsdaten SN 2023
# 99  energy_0100    Speicherstatus SH 2022
#
#                                           description  \
# 0   Datensatz mit erzeugungsdaten aus BY für das J...
# 1   Datensatz mit erzeugungsdaten aus SH für das J...
# 2   Datensatz mit speicherstatus aus HE für das Ja...
# 3   Datensatz mit wetterdaten aus HE für das Jahr ...
# 4   Datensatz mit verbrauchsdaten aus SH für das J...
# ..                                                ...
# 95  Datensatz mit speicherstatus aus SN für das Ja...
# 96  Datensatz mit erzeugungsdaten aus SH für das J...
# 97  Datensatz mit erzeugungsdaten aus NI für das J...
# 98  Datensatz mit erzeugungsdaten aus BY für das J...
# 99  Datensatz mit marktdaten aus BW für das Jahr 2...
#
#                   publisher       source_system    data_category granularity  \
# 0              SolarFlow SE       SmartMeterHub   Speicherstatus        1min
# 1        E-Mobility Connect       EdgeCollector  Erzeugungsdaten        1min
# 2        WattWise Analytics       EdgeCollector        Ladedaten      hourly
# 3        E-Mobility Connect  EnergyDataPlatform   Speicherstatus       15min
# 4   HydroEnergy Deutschland         IoT Gateway  Verbrauchsdaten       15min
# ..                      ...                 ...              ...         ...
# 95       E-Mobility Connect       EdgeCollector  Erzeugungsdaten       15min
# 96      SmartGrid Solutions            DataLake        Ladedaten       15min
# 97      SmartGrid Solutions  EnergyDataPlatform        Ladedaten       daily
# 98      SmartGrid Solutions       EdgeCollector         Netzlast        1min
# 99       E-Mobility Connect       SmartMeterHub  Erzeugungsdaten       15min
#
#    geographical_scope temporal_coverage_start temporal_coverage_end   format  \
# 0                  BY              2023-07-23            2024-01-30  Parquet
# 1                  BY              2023-10-10            2023-12-05  Parquet
# 2                 NRW              2023-10-28            2024-07-07     JSON
# 3                  NI              2023-08-05            2024-02-14  Parquet
# 4                 NRW              2022-11-21            2023-03-26      CSV
# ..                ...                     ...                   ...      ...
# 95                 BW              2022-09-10            2023-06-11  Parquet
# 96                 HE              2023-07-09            2024-07-05      XML
# 97                 SN              2023-09-30            2024-06-30      CSV
# 98                NRW              2023-04-20            2023-10-11      XML
# 99                 BE              2022-12-28            2023-10-29      CSV
#
#     size_mb update_frequency      license          created_at  \
# 0    146.77            daily  Proprietary 2022-06-22 17:15:51
# 1    186.54          monthly  Proprietary 2023-05-25 21:36:43
# 2    125.07           hourly  Proprietary 2022-03-29 23:48:11
# 3    183.53           hourly    CC-BY-4.0 2022-06-25 09:32:38
# 4     84.22          monthly       ODC-BY 2024-04-03 12:20:16
# ..      ...              ...          ...                 ...
# 95   172.98           weekly  Proprietary 2023-12-12 21:02:31
# 96    69.12           hourly          CC0 2022-08-25 05:14:59
# 97   133.64           weekly          CC0 2023-08-12 15:37:15
# 98   103.84           weekly          CC0 2023-03-08 14:04:38
# 99   167.37           weekly    CC-BY-4.0 2023-02-12 07:17:34
#
#          last_modified                          contact  \
# 0  2024-03-11 01:06:58         data-office@smartgrid.de
# 1  2022-10-23 09:36:17          data-office@wattwise.de
# 2  2023-06-12 08:08:45        data-office@e-mobility.de
# 3  2022-04-22 04:49:58          data-office@wattwise.de
# 4  2023-09-27 13:52:57        data-office@e-mobility.de
# ..                 ...                              ...
# 95 2024-03-20 23:10:47          data-office@wattwise.de
# 96 2024-02-05 18:46:59  data-office@energieversorger.de
# 97 2022-04-16 11:41:39         data-office@smartgrid.de
# 98 2024-01-02 09:06:41        data-office@e-mobility.de
# 99 2022-02-25 01:20:34       data-office@hydroenergy.de
#
#                                              keywords  quality_score
# 0                                [solar, strom, netz]           0.66
# 1                         [verbrauch, wind, haushalt]           0.99
# 2                  [wind, haushalt, zeitreihe, markt]           0.66
# 3                      [haushalt, netz, solar, markt]           0.98
# 4                      [solar, verbrauch, wind, netz]           0.79
# ..                                                ...            ...
# 95      [solar, wind, haushalt, zeitreihe, emobility]           0.67
# 96            [emobility, haushalt, verbrauch, markt]           0.82
# 97  [verbrauch, markt, emobility, haushalt, zeitre...           0.75
# 98                    [strom, netz, zeitreihe, solar]           0.79
# 99                 [haushalt, strom, emobility, wind]           0.82
#
# [100 rows x 19 columns]

# %%
df[df['publisher'].isin(['SolarFlow SE'])]
# Out:
#      dataset_id                title  \
# 0   energy_0001    Ladedaten BW 2023
# 10  energy_0032  Wetterdaten SH 2023
# 16  energy_0052  Wetterdaten HE 2023
#
#                                           description     publisher  \
# 0   Datensatz mit erzeugungsdaten aus BY für das J...  SolarFlow SE
# 10  Datensatz mit verbrauchsdaten aus BY für das J...  SolarFlow SE
# 16  Datensatz mit marktdaten aus SN für das Jahr 2...  SolarFlow SE
#
#          source_system   data_category granularity geographical_scope  \
# 0        SmartMeterHub  Speicherstatus        1min                 BY
# 10         IoT Gateway     Wetterdaten       15min                 SH
# 16  EnergyDataPlatform  Speicherstatus       15min                 BY
#
#    temporal_coverage_start temporal_coverage_end   format  size_mb  \
# 0               2023-07-23            2024-01-30  Parquet   146.77
# 10              2023-05-20            2023-09-19  Parquet    81.23
# 16              2023-07-20            2024-01-22  Parquet   174.07
#
#    update_frequency      license          created_at       last_modified  \
# 0             daily  Proprietary 2022-06-22 17:15:51 2024-03-11 01:06:58
# 10           weekly    CC-BY-4.0 2023-06-10 08:08:54 2022-12-15 04:13:27
# 16          monthly          CC0 2023-10-29 10:14:16 2024-12-07 12:18:22
#
#                             contact                      keywords  \
# 0          data-office@smartgrid.de          [solar, strom, netz]
# 10          data-office@wattwise.de  [solar, haushalt, zeitreihe]
# 16  data-office@energieversorger.de   [verbrauch, haushalt, wind]
#
#     quality_score
# 0            0.66
# 10           0.92
# 16           0.72

# %%
# count parquet in column format
df['format'].value_counts()
# Out:
# format
# Parquet    28
# CSV        25
# XML        25
# JSON       22
# Name: count, dtype: int64
